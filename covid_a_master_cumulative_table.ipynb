# %%
# Data from here:
# https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide
import pandas as pd
import glob
import os

# %%
# READ, RENAME
covid = pd.read_excel("COVID-19-geographic-disbtribution-worldwide-2020-08-27.xlsx") 
# REPLACED WITH THE CODE BELOW THAT EXTRACTS THE LATEST .xlsx FILE IN THE FOLDER

# list_of_files = glob.glob('C:\\Users\\nikan\\Documents\\CHE_DS_course\\CHE1148\\Week_03_Intro_to_Python\\02_Assignment_3_covid_visualization\\python_files/*xlsx') # * means all if need specific format then *.csv
# latest_file = max(list_of_files, key=os.path.getctime)
# print(latest_file)
# covid = pd.read_excel(latest_file) 
# print(type(covid))

# %%
covid
# Out:
#          dateRep  ...  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0     2020-08-27  ...                                           2.053007
# 1     2020-08-26  ...                                           2.108210
# 2     2020-08-25  ...                                           2.670749
# 3     2020-08-24  ...                                           2.484112
# 4     2020-08-23  ...                                           2.484112
# ...          ...  ...                                                ...
# 38906 2020-03-25  ...                                                NaN
# 38907 2020-03-24  ...                                                NaN
# 38908 2020-03-23  ...                                                NaN
# 38909 2020-03-22  ...                                                NaN
# 38910 2020-03-21  ...                                                NaN
#
# [38911 rows x 12 columns]

# %%
#Clear unwanted data, improve the titles and data entries for better understanding and aesthetic point of view
covid.rename(columns = {'countriesAndTerritories': 'Country'}, inplace = True)
covid.rename(columns = {'dateRep': 'DateRep', 'day':'Day', 'month':'Month','year':'Year','cases':'Cases','deaths':'Deaths', 'popData2019':'Population', 'continentExp':'Continent'}, inplace = True) #inplace does things right away. no nned to create a new file
covid.replace('CANADA','Canada', inplace=True)
covid.replace(['United_States_of_America', 'United_Kingdom', 'South_Korea', 'Saudi_Arabia', 'South_Africa', 'United_Arab_Emirates', 'Dominican_Republic'],['USA', 'UK', 'S.Korea', 'S.Arabia', 'S.Africa', 'UAE', 'Dom.Rep.'], inplace = True)
covid.drop(columns = ['geoId', 'countryterritoryCode', 'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'], inplace = True)
covid[covid['Country'] == 'Canada'] #filteration technique
# Out:
#         DateRep  Day  Month  Year  Cases  Deaths Country  Population Continent
# 6501 2020-08-27   27      8  2020    448       4  Canada  37411038.0   America
# 6502 2020-08-26   26      8  2020    322       7  Canada  37411038.0   America
# 6503 2020-08-25   25      8  2020    751      10  Canada  37411038.0   America
# 6504 2020-08-24   24      8  2020    267       2  Canada  37411038.0   America
# 6505 2020-08-23   23      8  2020    257       7  Canada  37411038.0   America
# ...         ...  ...    ...   ...    ...     ...     ...         ...       ...
# 6737 2020-01-04    4      1  2020      0       0  Canada  37411038.0   America
# 6738 2020-01-03    3      1  2020      0       0  Canada  37411038.0   America
# 6739 2020-01-02    2      1  2020      0       0  Canada  37411038.0   America
# 6740 2020-01-01    1      1  2020      0       0  Canada  37411038.0   America
# 6741 2019-12-31   31     12  2019      0       0  Canada  37411038.0   America
#
# [241 rows x 9 columns]

# %%
covid_cumulative = covid.groupby(['DateRep','Country']).sum() # this only makes the daterep and country the index of the table
covid_cumulative
# Out:
#                            Day  Month  Year  Cases  Deaths  Population
# DateRep    Country
# 2019-12-31 Afghanistan      31     12  2019      0       0  38041757.0
#            Algeria          31     12  2019      0       0  43053054.0
#            Armenia          31     12  2019      0       0   2957728.0
#            Australia        31     12  2019      0       0  25203200.0
#            Austria          31     12  2019      0       0   8858775.0
# ...                        ...    ...   ...    ...     ...         ...
# 2020-08-27 Vietnam          27      8  2020      5       3  96462108.0
#            Western_Sahara   27      8  2020      0       0    582458.0
#            Yemen            27      8  2020      6       3  29161922.0
#            Zambia           27      8  2020     91       0  17861034.0
#            Zimbabwe         27      8  2020     55      13  14645473.0
#
# [38911 rows x 6 columns]

# %%
# GENERATE THE CUMULATIVE COUNTS
covid_cumulative = covid.groupby(['DateRep','Country']).sum().groupby('Country').cumsum() #groupby is the best function for cumulative data
covid_cumulative['Date'] = covid_cumulative.index.get_level_values(0)
covid_cumulative['Countries'] = covid_cumulative.index.get_level_values(1)
covid_cumulative.drop(columns=['Population', 'Day', 'Month', 'Year'], inplace = True)
covid_cumulative
covid_cumulative[covid_cumulative['Countries'] == 'Canada']
# Out:
#                      Cases  Deaths       Date Countries
# DateRep    Country
# 2019-12-31 Canada        0       0 2019-12-31    Canada
# 2020-01-01 Canada        0       0 2020-01-01    Canada
# 2020-01-02 Canada        0       0 2020-01-02    Canada
# 2020-01-03 Canada        0       0 2020-01-03    Canada
# 2020-01-04 Canada        0       0 2020-01-04    Canada
# ...                    ...     ...        ...       ...
# 2020-08-23 Canada   124629    9071 2020-08-23    Canada
# 2020-08-24 Canada   124896    9073 2020-08-24    Canada
# 2020-08-25 Canada   125647    9083 2020-08-25    Canada
# 2020-08-26 Canada   125969    9090 2020-08-26    Canada
# 2020-08-27 Canada   126417    9094 2020-08-27    Canada
#
# [241 rows x 4 columns]

# %%
# RE-JOIN TO GET COUNTRY'S POPULATIONS
covid_cumulative = covid_cumulative.merge(covid[['DateRep', 'Country', 'Population', 'Continent']], how='inner', left_index=True, right_on=['DateRep', 'Country']).set_index(['DateRep', 'Country'])
covid_cumulative
# Out:
#                            Cases  Deaths  ...  Population Continent
# DateRep    Country                        ...
# 2019-12-31 Afghanistan         0       0  ...  38041757.0      Asia
#            Algeria             0       0  ...  43053054.0    Africa
#            Armenia             0       0  ...   2957728.0    Europe
#            Australia           0       0  ...  25203200.0   Oceania
#            Austria             0       0  ...   8858775.0    Europe
# ...                          ...     ...  ...         ...       ...
# 2020-08-27 Vietnam          1034      30  ...  96462108.0      Asia
#            Western_Sahara    766       1  ...    582458.0    Africa
#            Yemen            1930     560  ...  29161922.0      Asia
#            Zambia          11376     282  ...  17861034.0    Africa
#            Zimbabwe         6251     179  ...  14645473.0    Africa
#
# [38911 rows x 6 columns]

# %%
covid_cumulative = covid_cumulative.reset_index()#.drop(columns=['DateRep', 'Country'])
covid_cumulative
covid_cumulative.to_excel('covid_a_master_cumulative_table.xlsx')

# %%
covid_cumulative
# Out:
#          DateRep         Country  Cases  ...       Countries  Population Continent
# 0     2019-12-31     Afghanistan      0  ...     Afghanistan  38041757.0      Asia
# 1     2019-12-31         Algeria      0  ...         Algeria  43053054.0    Africa
# 2     2019-12-31         Armenia      0  ...         Armenia   2957728.0    Europe
# 3     2019-12-31       Australia      0  ...       Australia  25203200.0   Oceania
# 4     2019-12-31         Austria      0  ...         Austria   8858775.0    Europe
# ...          ...             ...    ...  ...             ...         ...       ...
# 38906 2020-08-27         Vietnam   1034  ...         Vietnam  96462108.0      Asia
# 38907 2020-08-27  Western_Sahara    766  ...  Western_Sahara    582458.0    Africa
# 38908 2020-08-27           Yemen   1930  ...           Yemen  29161922.0      Asia
# 38909 2020-08-27          Zambia  11376  ...          Zambia  17861034.0    Africa
# 38910 2020-08-27        Zimbabwe   6251  ...        Zimbabwe  14645473.0    Africa
#
# [38911 rows x 8 columns]
